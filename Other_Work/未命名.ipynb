# %%
import tensorflow as tf
from tensorflow.keras import layers
from PIL import Image
import os
import pathlib
import pathlib
import shutil
import numpy as np
import pandas as pd

# %%
path = './Pictures/negative'
files_name = os.listdir(path)
for score in files_name:
    files = path + '/' + score
    scores = int((score.split('--')[-1]).replace('.jpg',''))
    print(scores)
    if scores >= 128:
        shutil.copy( files, base_path+"/P/"+score)
    else:
        print(files)
        shutil.copy( files, base_path+"/N/"+score)
# Out:
# 74
# ./Pictures/negative/img_F8N94277-202104_28--10_26_36--074.jpg
# 138
# 236
# 186
# 190
# 222
# 247
# 239
# 74
# ./Pictures/negative/img_F8N94277-202104_28--10_27_55--074.jpg
# 254
# 236
# 83
# ./Pictures/negative/img_F8N94277-202104_28--10_28_26--083.jpg
# 241
# 138
# 249
# 234
# 202
# 182
# 251
# 254
# 247
# 249
# 253
# 248
# 254
# 123
# ./Pictures/negative/img_F8N94277-202104_28--10_31_05--123.jpg
# 0
# ./Pictures/negative/img_F8N94277-202104_28--10_31_15--000.jpg
# 3
# ./Pictures/negative/img_F8N94277-202104_28--10_31_25--003.jpg
# 0
# ./Pictures/negative/img_F8N94277-202104_28--10_31_35--000.jpg
# 0
# ./Pictures/negative/img_F8N94277-202104_28--10_31_45--000.jpg
# 0
# ./Pictures/negative/img_F8N94277-202104_28--10_31_55--000.jpg
# 0
# ./Pictures/negative/img_F8N94277-202104_28--10_32_05--000.jpg
# 1
# ./Pictures/negative/img_F8N94277-202104_28--10_32_14--001.jpg
# 2
# ./Pictures/negative/img_F8N94277-202104_28--10_32_25--002.jpg
# 0
# ...

# %%
import shutil
base_path = "./Classification"
def create_examination(base_path):
    os.makedirs(base_path)
    os.makedirs(base_path+"/P")
    os.makedirs(base_path+"/N")
    return None

if not os.path.exists(base_path):
    create_examination(base_path)
else:
    shutil.rmtree(base_path)
    create_examination(base_path)
